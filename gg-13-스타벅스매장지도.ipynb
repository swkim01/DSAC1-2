# %% [markdown]
# # 스타벅스 매장 데이터와 지도
#
#
# * json_normalize(): JSON 데이터 DataFrame으로 전환
# * folium 을 사용하여 지도에 위치 표시
#
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/github/swkim01/DSAC1-2/blob/main/gg-13-스타벅스매장지도.ipynb"><img src="https://github.com/swkim01/DSAC1-2/raw/main/colab_logo_32px.png" />구글 코랩에서 실행</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/swkim01/DSAC1-2/blob/main/gg-13-스타벅스매장지도.ipynb"><img src="https://github.com/swkim01/DSAC1-2/raw/main/GitHub-Mark-32px.png" />깃헙에서 소스 보기</a>
#   </td>
# </table>

# %% [markdown]
# # 스타벅스 매장찾기
# http://www.istarbucks.co.kr
#
# * STORE >> 매장 찾기
# * 지역검색 >> 서울 >> 전체

# %%
import requests
import json
import pandas as pd
from pandas.io.json import json_normalize
# %config InlineBackend.figure_format = 'retina'

# %%
data = {
    'ins_lat':'37.56682', # 지정한 위도와 경도에서 가까운 순으로 나열
    'ins_lng':'126.97865',
    'p_sido_cd':'01', # 01=서울시, 08=경기 ... 16=제주
    'p_gugun_cd':'',  # 세부지역 (지정하지 않으면 시/도 전체)
    'in_biz_cd':'',
    'set_date':'',
    'iend':'1000',
}
    
url = 'https://www.istarbucks.co.kr/store/getStore.do'
r = requests.post(url, data=data)

r.text[:1000] # 수신된 데이터의 앞부분만 확인
# Out:
# '{"list":[{"seq":0,"sido_cd":null,"sido_nm":null,"gugun_cd":null,"gugun_nm":null,"code_order":null,"view_yn":null,"store_num":null,"sido":null,"gugun":null,"address":null,"new_img_nm":null,"p_pro_seq":0,"p_view_yn":null,"p_sido_cd":"","p_gugun_cd":"","p_store_nm":null,"p_theme_cd":null,"p_wireless_yn":null,"p_smoking_yn":null,"p_book_yn":null,"p_music_yn":null,"p_terrace_yn":null,"p_table_yn":null,"p_takeout_yn":null,"p_parking_yn":null,"p_dollar_assent":null,"p_card_recharge":null,"p_subway_yn":null,"stb_store_file_renew":null,"stb_store_theme_renew":null,"stb_store_time_renew":null,"stb_store_lsm":null,"s_code":"1509","s_name":"역삼아레나빌딩","tel":"02-568-3762","fax":"02-568-3763","sido_code":"01","sido_name":"서울","gugun_code":"0101","gugun_name":"강남구","addr":"서울특별시 강남구 역삼동 721-13 아레나빌딩","park_info":null,"new_state":null,"theme_state":"T04@T05@T08@T16@T17@T20@T21@P80@P90","new_bool":0,"search_text":"","ins_lat":"","ins_lng":"","in_distance":0,"out_distance":"9.26","all_search_cnt":-1,"addr'

# %% [markdown]
# 데이터는 JSON으로 수신되며, 형태는 다음과 같다.
#
# ```json
# {
#   "list": [
#       {
#             // ... 중략 ...
#             "s_code": "1311",
#             "s_name": "방화DT",
#             "tel": "02-2664-3480",
#             "fax": "02-2664-3481",
#             "sido_code": "01",
#             "sido_name": "서울",
#             "gugun_code": "0103",
#             "gugun_name": "강서구",
#             "addr": "서울특별시 강서구 방화동 293-4",
#             "park_info": null,
#             "new_state": null,
#             "theme_state": "T17@T16@T09@T20@T01@T05@T08@T04",
#             // ... 중략 ...
#             "lat": "37.574339",
#             "lot": "126.816415",
#             "t22": 0
#         },
#         {
#             // ... 중략 ...
#             "s_code": "1267",
#             "s_name": "마곡나루역",
#             "tel": "02-3662-3504",
#             "fax": "02-3662-3505",
#             "sido_code": "01",
#             "sido_name": "서울",
#             "gugun_code": "0103",
#             "gugun_name": "강서구",
#             "addr": "서울특별시 강서구 마곡동 759-3 보타닉파크타워Ⅰ105,203,204호",
#             "park_info": null,
#             "new_state": null,
#             "theme_state": "T08@T05@T04@T17@T16@P80@T20",
#             // ... 중략 ...
#             "lat": "37.56813",
#             "lot": "126.82614",
#             "t22": 0
#         },
#     ]
#  }
# ```

# %% [markdown]
# # JSON to DataFrame
#
# json_normalize() 를 사용하여 JSON 데이터를 DataFrame로 전환

# %%
jo = json.loads(r.text)
df = json_normalize(jo, 'list')

# %%
# 행(row)수, 서울 457개 매장
len(df)
# Out:
# 495

# %%
# 컬럼수 111개
df.columns
# Out:
# Index(['addr', 'addr_search_cnt', 'address', 'all_search_cnt', 'code_order',
#        'cold_blew', 'defaultimage', 'disp', 'doro_address', 'espresso',
#        ...
#        't10', 't12', 't20', 't21', 't22', 'tel', 'theme_state', 'vSal',
#        'view_yn', 'whcroad_yn'],
#       dtype='object', length=118)

# %%
# 주요한 컬럼 몇 가지 선택
               
df = df[['s_name', 'lat', 'lot', 'sido_name', 'gugun_name', 'doro_address', 'tel']]
df.head(20)
# Out:
#        s_name         lat         lot sido_name gugun_name  \
# 0     역삼아레나빌딩   37.501087  127.043069        서울        강남구
# 1      논현역사거리   37.510178  127.022223        서울        강남구
# 2     대치대원빌딩R   37.494668  127.062583        서울        강남구
# 3    삼성역섬유센터R   37.507750  127.060651        서울        강남구
# 4        압구정R  37.5273669  127.033061        서울        강남구
# 5        수서역R   37.488008  127.102650        서울        강남구
# 6     양재강남빌딩R   37.485192  127.036685        서울        강남구
# 7     선릉동신빌딩R   37.505321  127.050409        서울        강남구
# 8     봉은사로선정릉   37.511293  127.048409        서울        강남구
# 9       강남오거리   37.502117  127.026672        서울        강남구
# 10  스타필드코엑스몰R    37.50999  127.061455        서울        강남구
# 11     강남구청정문   37.518181  127.045995        서울        강남구
# 12       도곡공원   37.492805  127.041309        서울        강남구
# 13        강남R   37.497711  127.028439        서울        강남구
# 14    대치은마사거리   37.498973  127.060172        서울        강남구
# 15     청담영동대로   37.522156  127.056449        서울        강남구
# 16        압구정   37.526283  127.029560        서울        강남구
# 17      신사가로수   37.521852  127.022510        서울        강남구
# 18      청담스타R   37.525216  127.041827        서울        강남구
# 19       강남우성   37.492396  127.030910        서울        강남구
#
#                   doro_address           tel
# 0      서울특별시 강남구 언주로 425 (역삼동)   02-568-3762
# 1     서울특별시 강남구 강남대로 538 (논현동)  02-3442-3672
# 2   서울특별시 강남구 남부순환로 2947 (대치동)   02-568-3704
# 3     서울특별시 강남구 테헤란로 518 (대치동)   02-568-3648
# 4      서울특별시 강남구 언주로 861 (신사동)   02-541-3622
# 5      서울특별시 강남구 광평로 281 (수서동)  02-6181-3688
# 6   서울특별시 강남구 남부순환로 2621 (도곡동)   02-571-3604
# 7     서울특별시 강남구 테헤란로 409 (삼성동)  02-2051-3562
# 8     서울특별시 강남구 봉은사로 446 (삼성동)   02-539-3564
# 9    서울특별시 강남구 봉은사로2길 39 (역삼동)   02-557-3484
# 10    서울특별시 강남구 영동대로 513 (삼성동)  02-6002-3467
# 11     서울특별시 강남구 학동로 419 (청담동)   02-514-3397
# 12     서울특별시 강남구 도곡로 205 (역삼동)   02-565-3496
# 13    서울특별시 강남구 강남대로 390 (역삼동)   02-561-3478
# 14     서울특별시 강남구 도곡로 457 (대치동)   02-554-3315
# 15    서울특별시 강남구 영동대로 720 (청담동)  02-3443-3371
# 16  서울특별시 강남구 압구정로30길 17 (신사동)   02-541-3306
# 17  서울특별시 강남구 압구정로12길 32 (신사동)  02-3446-3356
# 18  서울특별시 강남구 도산대로57길 24 (청담동)   02-514-3364
# 19    서울특별시 강남구 강남대로 328 (역삼동)   02-565-3347

# %% [markdown]
# # 위도 경도 데이터 타입 변환

# %%
df.dtypes
# Out:
# s_name          object
# lat             object
# lot             object
# sido_name       object
# gugun_name      object
# doro_address    object
# tel             object
# dtype: object

# %% [markdown]
# ### lat, lot타입으로 전환 (str→float)

# %%
df['lat'] = df['lat'].astype(float)
df['lot'] = df['lot'].astype(float)

# %%
df.dtypes
# Out:
# s_name           object
# lat             float64
# lot             float64
# sido_name        object
# gugun_name       object
# doro_address     object
# tel              object
# dtype: object

# %% [markdown]
# ### 특정 지점

# %%
df[df['s_name'] == '시청'] # 시청점
# Out:
#     s_name       lat         lot sido_name gugun_name  \
# 426     시청  37.56629  126.979808        서울         중구
#
#                              doro_address          tel
# 426  서울특별시 중구 을지로 19, 삼성화재삼성빌딩 1층 (을지로1가)  02-758-8504

# %% [markdown]
# 스타벅스 시청점의 위도(lat)와 경도(lot)는 각각  37.56629, 126.979808

# %% [markdown]
# # folium
# https://github.com/python-visualization/folium
#
# 파이썬 지리정보 시각화 모듈  (문서: https://folium.readthedocs.io )

# %%
# !pip install folium
# Out:
# Collecting folium
#   Downloading https://files.pythonhosted.org/packages/4f/86/1ab30184cb60bc2b95deffe2bd86b8ddbab65a4fac9f7313c278c6e8d049/folium-0.9.1-py2.py3-none-any.whl (91kB)
# Requirement already satisfied: jinja2>=2.9 in c:\users\ojkwon\anaconda3\lib\site-packages (from folium) (2.10)
# Requirement already satisfied: requests in c:\users\ojkwon\anaconda3\lib\site-packages (from folium) (2.21.0)
# Collecting branca>=0.3.0 (from folium)
#   Downloading https://files.pythonhosted.org/packages/63/36/1c93318e9653f4e414a2e0c3b98fc898b4970e939afeedeee6075dd3b703/branca-0.3.1-py3-none-any.whl
# Requirement already satisfied: numpy in c:\users\ojkwon\anaconda3\lib\site-packages (from folium) (1.15.4)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\ojkwon\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (1.1.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\ojkwon\anaconda3\lib\site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ojkwon\anaconda3\lib\site-packages (from requests->folium) (2018.11.29)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in c:\users\ojkwon\anaconda3\lib\site-packages (from requests->folium) (1.24.1)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\ojkwon\anaconda3\lib\site-packages (from requests->folium) (2.8)
# Requirement already satisfied: six in c:\users\ojkwon\anaconda3\lib\site-packages (from branca>=0.3.0->folium) (1.12.0)
# Installing collected packages: branca, folium
# Successfully installed branca-0.3.1 folium-0.9.1
# WARNING: You are using pip version 19.1, however version 19.1.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
import folium

# 서울 시청 
map_osm = folium.Map(location=(37.56629, 126.979808))
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# 지도를 상하좌우로 움직이거나 확대/축소 할 수 있다

# %%
# 확대 지정 (zoom_start)
map_osm = folium.Map(location=(37.56629, 126.979808), zoom_start=17)
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# 지도 tiles 지정
map_osm = folium.Map(location=(37.56629, 126.979808), zoom_start=17, tiles='Stamen Toner')
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
시청_좌표=(37.56629, 126.979808)
 
map_osm = folium.Map(location=시청_좌표, zoom_start=17)
folium.Marker(시청_좌표, popup='시청').add_to(map_osm)
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # 서울 스타벅스 전 지점

# %%
map_osm = folium.Map(location=시청_좌표, zoom_start=11)

for ix, row in df.iterrows():
    location = (row['lat'], row['lot'])
    folium.Marker(location, popup=row['s_name']).add_to(map_osm)

map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # 제주도 스타벅스 매장 지도

# %%
import requests
import json
import pandas as pd
from pandas.io.json import json_normalize

한라산_좌표 = (33.361666, 126.529166)

data = {
    'ins_lat': '33.4996213', # 제주 시청의 좌표
    'ins_lng': '126.5311884',
    'p_sido_cd':'16', # 01=서울시, 08=경기 ... 16=제주
    'p_gugun_cd':'',  # 세부지역 (지정하지 않으면 시/도 전체)
    'in_biz_cd':'',
    'set_date':'',
    'iend':'1000',
}
    
url = 'https://www.istarbucks.co.kr/store/getStore.do'
r = requests.post(url, data=data)
df = json_normalize(json.loads(r.text), 'list')

map_osm = folium.Map(location=(33.361666, 126.529166), zoom_start=10)
for ix, row in df.iterrows():
    location = (row['lat'], row['lot'])
    folium.Marker(location, popup=row['s_name']).add_to(map_osm)

map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df[['s_name', 'gugun_name', 'doro_address', 'tel']]
# Out:
#      s_name gugun_name                             doro_address           tel
# 0   제주신화월드R       서귀포시     제주특별자치도 서귀포시 안덕면 신화역사로304번길 38 B1-29  064-908-1729
# 1    제주에듀시티       서귀포시               제주특별자치도 서귀포시 대정읍 에듀시티로 36   064-792-3371
# 2    제주성산DT       서귀포시                 제주특별자치도 서귀포시 성산읍 일출로 80   064-782-3273
# 3    제주중문DT       서귀포시                제주특별자치도 서귀포시 천제연로 95(색달동)  064-738-8915
# 4     제주서귀포       서귀포시                제주특별자치도 서귀포시 중정로 53 (서귀동)  064-763-8707
# 5     제주송악산       서귀포시             제주특별자치도 서귀포시 형제해안로 322 (상모리)  064-792-8731
# 6     서귀포DT       서귀포시               제주특별자치도 서귀포시 일주서로 11 (강정동)  064-738-5943
# 7     성산일출봉       서귀포시         제주특별자치도 서귀포시 성산읍 일출로 284-5, 1,2층  064-782-8535
# 8      제주중문       서귀포시         제주특별자치도 서귀포시 중문관광로110번길 32 (색달동)  064-738-8510
# 9      제주시청        제주시               제주특별자치도 제주시 중앙로 215 (이도이동)  064-756-3511
# 10     제주함덕        제주시               제주특별자치도 제주시 조천읍 조함해안로 522   064-783-3537
# 11   제주노형공원        제주시                 제주특별자치도 제주시 연북로 12 (노형동)  064-746-3367
# 12   제주애월DT        제주시               제주특별자치도 제주시 애월읍 애월해안로 376   064-799-3273
# 13     제주칠성        제주시                제주특별자치도 제주시 관덕로 55 (일도일동)  064-757-9892
# 14     제주노형        제주시                 제주특별자치도 제주시 도령로 27 (노형동)  064-745-8914
# 15   제주용담DT        제주시       제주특별자치도 제주시 서해안로 380 (용담삼동) 화이트하우스  064-745-9817
# 16   신제주이마트        제주시  제주특별자치도 제주시 1100로 3348, 신제주이마트 1층 (노형동)  064-748-8657

# %% [markdown]
# # 요약
# * requests.post() 데이터 가져오기
# * json_normalize(): JSON 데이터 DataFrame으로 전환
# * folium 을 사용하여 지도에 위치 표시

# %% [markdown]
# ### 2018 FinanceData.KR [fb.com/financedata](fb.com/financedata)
